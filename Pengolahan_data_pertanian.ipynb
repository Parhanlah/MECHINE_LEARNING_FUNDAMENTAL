# %% [markdown]
# <a href="https://colab.research.google.com/github/Parhanlah/MECHINE_LEARNING_FUNDAMENTAL/blob/main/Pengolahan_data_pertanian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FARKHAN ADI NAUFAL HAFIDH G.211.21.0090

# %% [markdown]
# #MUHAMMAD SAFUWAN               G.211.21.0108

# %% [markdown]
# #ROHY BIMO SUBIANTO          G.211.21.0118

# %% [markdown]
# #**PERSIAPAN** **DATA**

# %%
#Mengimport seluruh module yang dibutuhkan
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
# %matplotlib inline
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7f53a62e-dbba-4522-95e0-97043e02398b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f53a62e-dbba-4522-95e0-97043e02398b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#membaca dataset
data = pd.read_csv("data - Sheet1.csv")

# %%
#memahami bentuk data dalam dataset
data.shape
# Out:
# (15, 8)

# %%
data.columns
# Out:
# Index(['nama_petani', 'jenis_padi', 'harga_bibit', 'masa_pembibitan',
#        'masa_tanam', 'luas_tanah', 'jumlah_panen', 'hasil_panen'],
#       dtype='object')

# %%
# Statistik deskriptif
data.describe()
# Out:
#          harga_bibit  masa_pembibitan  masa_tanam  luas_tanah  jumlah_panen  \
# count      15.000000        15.000000   15.000000   15.000000     15.000000
# mean    67666.666667        19.533333  101.666667    3.666667      2.733333
# std     15682.869028         2.199567   10.801234    1.799471      0.457738
# min     55000.000000        15.000000   70.000000    1.000000      2.000000
# 25%     60000.000000        17.000000  105.000000    3.000000      2.500000
# 50%     65000.000000        21.000000  105.000000    3.000000      3.000000
# 75%     65000.000000        21.000000  105.000000    5.000000      3.000000
# max    105000.000000        21.000000  115.000000    7.000000      3.000000
#
#        hasil_panen
# count     15.00000
# mean      49.60000
# std       31.91238
# min        6.00000
# 25%       30.00000
# 50%       51.00000
# 75%       61.00000
# max      120.00000

# %%
#memahami data dan atribut dalam dataset
print("\nInformasi Data:")
print(data.info())
# Out:
# Informasi Data:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   nama_petani      15 non-null     object
#  1   jenis_padi       15 non-null     object
#  2   harga_bibit      15 non-null     int64
#  3   masa_pembibitan  15 non-null     int64
#  4   masa_tanam       15 non-null     int64
#  5   luas_tanah       15 non-null     int64
#  6   jumlah_panen     15 non-null     int64
#  7   hasil_panen      15 non-null     int64
# dtypes: int64(6), object(2)
# memory usage: 1.1+ KB
# None

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# nama_petani        15
# jenis_padi          9
# harga_bibit         4
# masa_pembibitan     3
# masa_tanam          5
# luas_tanah          7
# jumlah_panen        2
# hasil_panen        14
# dtype: int64

# %%
#mengecek null
data.isnull().sum()
# Out:
# nama_petani        0
# jenis_padi         0
# harga_bibit        0
# masa_pembibitan    0
# masa_tanam         0
# luas_tanah         0
# jumlah_panen       0
# hasil_panen        0
# dtype: int64

# %%
data.apply(lambda x: len(x.unique()))
# Out:
# Unnamed: 0                 15
# nama_petani                15
# jenis_padi                  9
# harga_bibit                 4
# masa_pembibitan             3
# masa_tanam                  5
# luas_tanah                 13
# jumlah_panen_satu_tahun     2
# hasil_panen                14
# dtype: int64

# %%
f,ax=plt.subplots(figsize=(12,6))
corr=data.corr()
sns.heatmap(corr , ax=ax , cmap="rocket")
# Out:
# <ipython-input-17-13d5dd31de7e>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr()
# <Axes: >

# %%
f= plt.figure(figsize=(20,5))
ax=f.add_subplot(121)
sns.distplot(data['harga_bibit'] , color ='yellow',ax=ax)

ax=f.add_subplot(122)
sns.distplot(data['hasil_panen'] , color='blue' , ax=ax)
plt.tight_layout()
# Out:
# <ipython-input-19-ac8e0a4346dc>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['harga_bibit'] , color ='yellow',ax=ax)
# <ipython-input-19-ac8e0a4346dc>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['hasil_panen'] , color='blue' , ax=ax)

# %%
f= plt.figure(figsize=(20,5))
ax=f.add_subplot(121)
sns.distplot(data['masa_pembibitan'] , color ='green',ax=ax)

ax=f.add_subplot(122)
sns.distplot(data['masa_tanam'] , color='black' , ax=ax)
plt.tight_layout()
# Out:
# <ipython-input-20-ea334403a204>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['masa_pembibitan'] , color ='green',ax=ax)
# <ipython-input-20-ea334403a204>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['masa_tanam'] , color='black' , ax=ax)

# %%
f= plt.figure(figsize=(20,5))
ax=f.add_subplot(121)
sns.distplot(data['luas_tanah'] , color ='blue',ax=ax)

ax=f.add_subplot(122)
sns.distplot(data['hasil_panen'] , color='red' , ax=ax)
plt.tight_layout()
# Out:
# <ipython-input-37-24255ec3566a>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['luas_tanah'] , color ='blue',ax=ax)
# <ipython-input-37-24255ec3566a>:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['hasil_panen'] , color='red' , ax=ax)

# %%
sns.distplot(data['hasil_panen'],color = 'green')
# Out:
# <ipython-input-58-bf74cfc85f14>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['hasil_panen'],color = 'green')
# <Axes: xlabel='hasil_panen', ylabel='Density'>

# %%
sns.barplot(x=data['harga_bibit'].value_counts().index,
y=data['harga_bibit'].value_counts(), palette='Spectral')
plt.xticks(rotation=90)
plt.show()

# %%
data.dropna(inplace=True)

# %%
f = plt.figure(figsize=(12,4))
sns.histplot(data['jenis_padi'])
plt.title('Jenis Padi Pilihan Petani')
plt.show()

# %% [markdown]
# #**Melihat Selisih Luas Tanah Dengan Hasi Panen**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca dataset menggunakan Pandas
dataset = pd.read_csv('data - Sheet1.csv')

# Pilih kolom 'luas_tanah' dan 'hasil_panen'
hasil_panen = dataset['hasil_panen']
luas_tanah = dataset['luas_tanah']

# Hitung rata-rata untuk setiap kolom
rata_rata_hasil_panen = hasil_panen.mean()
rata_rata_luas_tanah = luas_tanah.mean()

# Hitung selisih rata-rata
selisih_rata_rata =  rata_rata_hasil_panen - rata_rata_luas_tanah

# Tampilkan hasil perbandingan
print("Perbandingan antara luas_tanah dan hasil_panen:")
print(f"Rata-rata hasil_panen: {rata_rata_hasil_panen}")
print(f"Rata-rata luas_tanah: {rata_rata_luas_tanah}")
print(f"Selisih rata-rata: {selisih_rata_rata}")

# Visualisasi data
plt.figure(figsize=(12, 5))
plt.scatter(luas_tanah, hasil_panen, alpha=0.5)
plt.title('Perbandingan antara Luas Tanah dan Hasil Panen')
plt.xlabel('Luas Tanah')
plt.ylabel('Hasil Panen')
plt.grid(True)
plt.show()
# Out:
# Perbandingan antara luas_tanah dan hasil_panen:
# Rata-rata hasil_panen: 49.6
# Rata-rata luas_tanah: 3.6666666666666665
# Selisih rata-rata: 45.93333333333334

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca dataset menggunakan Pandas
dataset = pd.read_csv('data - Sheet1.csv')

# Pilih kolom 'harga_bibit' dan 'hasil_panen'
harga_bibit = dataset['harga_bibit']
hasil_panen = dataset['hasil_panen']

# Hitung rata-rata untuk setiap kolom
rata_rata_hasil_panen = hasil_panen.mean()
rata_rata_harga_bibit = harga_bibit.mean()

# Hitung selisih rata-rata
selisih_rata_rata = rata_rata_hasil_panen - rata_rata_harga_bibit

# Tampilkan hasil perbandingan
print("Perbandingan antara harga_bibit dan hasil_panen:")
print(f"Rata-rata hasil_panen: {rata_rata_hasil_panen}")
print(f"Rata-rata harga_bibit: {rata_rata_harga_bibit}")
print(f"Selisih rata-rata: {selisih_rata_rata}")

# Visualisasi data
plt.figure(figsize=(12, 5))
plt.scatter(harga_bibit, hasil_panen, alpha=0.5)
plt.title('Perbandingan antara Harga Bibit dan Hasil Panen')
plt.xlabel('Harga Bibit')
plt.ylabel('Hasil Panen')
plt.grid(True)
plt.show()
# Out:
# Perbandingan antara harga_bibit dan hasil_panen:
# Rata-rata hasil_panen: 49.6
# Rata-rata harga_bibit: 67666.66666666667
# Selisih rata-rata: -67617.06666666667

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca dataset menggunakan Pandas
dataset = pd.read_csv('data - Sheet1.csv')

# Pilih kolom 'jenis_padi', 'harga_bibit', dan 'hasil_panen'
jenis_padi = dataset['jenis_padi']
harga_bibit = dataset['harga_bibit']
hasil_panen = dataset['hasil_panen']

# Gabungkan kolom-kolom ke dalam satu DataFrame baru
rekomendasi_df = pd.DataFrame({'jenis_padi': jenis_padi, 'harga_bibit': harga_bibit, 'hasil_panen': hasil_panen})

# Urutkan DataFrame berdasarkan hasil panen terbanyak dan harga terendah
rekomendasi_df = rekomendasi_df.sort_values(by=['hasil_panen', 'harga_bibit'], ascending=[False, True])

# Tampilkan hasil rekomendasi
print("\nRekomendasi Harga Bibit berdasarkan Hasil Panen Terbanyak dan Harga Terendah:")
print(rekomendasi_df[['jenis_padi', 'hasil_panen', 'harga_bibit']].head())

# Visualisasi hasil rekomendasi dalam bentuk bar plot
plt.figure(figsize=(12, 6))
plt.bar(rekomendasi_df.index, rekomendasi_df['harga_bibit'], color='skyblue')
plt.title('Rekomendasi Harga Bibit berdasarkan Hasil Panen Terbanyak dan Harga Terendah')
plt.xlabel('Varietas Padi')
plt.ylabel('Harga Bibit')
plt.xticks(rekomendasi_df.index, rekomendasi_df['jenis_padi'], rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Rekomendasi Harga Bibit berdasarkan Hasil Panen Terbanyak dan Harga Terendah:
#    jenis_padi  hasil_panen  harga_bibit
# 8       umbul          120        55000
# 14      umbul           98        55000
# 11  impari 42           78        65000
# 0   impari 32           66        65000
# 6   impari 42           56        65000

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca dataset menggunakan Pandas
dataset = pd.read_csv('data - Sheet1.csv')

# Pilih kolom 'jenis_padi', 'harga_bibit', dan 'hasil_panen'
jenis_padi = dataset['jenis_padi']
harga_bibit = dataset['harga_bibit']
hasil_panen = dataset['hasil_panen']

# Gabungkan kolom-kolom ke dalam satu DataFrame baru
rekomendasi_df = pd.DataFrame({'jenis_padi': jenis_padi, 'harga_bibit': harga_bibit, 'hasil_panen': hasil_panen})

# Urutkan DataFrame berdasarkan hasil panen terbanyak dan harga terendah
rekomendasi_df = rekomendasi_df.sort_values(by=['hasil_panen', 'harga_bibit'], ascending=[False, True])

# Visualisasi hasil rekomendasi
plt.figure(figsize=(12, 8))

# Bar plot untuk 'hasil_panen' dan 'harga_bibit'
plt.subplot(2, 1, 1)
plt.bar(rekomendasi_df.index, rekomendasi_df['hasil_panen'], label='Hasil Panen', color='green', alpha=0.7)
plt.bar(rekomendasi_df.index, rekomendasi_df['harga_bibit'], label='Harga Bibit', color='blue', alpha=0.7)
plt.title('Hasil Panen dan Harga Bibit berdasarkan Rekomendasi')
plt.xlabel('Varietas Padi')
plt.ylabel('Nilai')
plt.legend()

# Line plot untuk 'jenis_padi'
plt.subplot(2, 1, 2)
plt.plot(rekomendasi_df.index, rekomendasi_df['jenis_padi'], marker='o', linestyle='-', color='red')
plt.title('Jenis Padi berdasarkan Rekomendasi')
plt.xlabel('Varietas Padi')
plt.ylabel('Jenis Padi')

plt.tight_layout()
plt.show()

# %% [markdown]
# #**Jenis Padi Yang Kami Rekomendasikan**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari file CSV
data = pd.read_csv('data - Sheet1.csv')

# Tampilkan beberapa baris pertama data untuk melihat strukturnya
print("Beberapa Baris Pertama Data:")
print(data.head())

# Menghitung rata-rata hasil_panen per 1 hektar untuk setiap jenis padi
data['hasil_panen_per_hektar'] = data['hasil_panen'] / data['luas_tanah']

rata_rata_hasil_panen_per_hektar = data.groupby('jenis_padi')['hasil_panen_per_hektar'].mean()

# Rekomendasikan jenis padi berdasarkan rata-rata hasil panen tertinggi per 1 hektar
varietas_rekomendasi = rata_rata_hasil_panen_per_hektar.sort_values(ascending=False).index.tolist()

# Tampilkan hasil rekomendasi
print("\nJenis Padi yang Direkomendasikan Berdasarkan Rata-rata Hasil Panen Tertinggi per 1 Hektar:")
print(varietas_rekomendasi[:3])  # Menampilkan tiga jenis padi pertama

# Visualisasi hasil rekomendasi
plt.figure(figsize=(12, 3))
plt.bar(varietas_rekomendasi[:3], rata_rata_hasil_panen_per_hektar[varietas_rekomendasi[:3]])
plt.title('Rekomendasi Jenis Padi Berdasarkan Rata-rata Hasil Panen Tertinggi per 1 Hektar')
plt.xlabel('Jenis Padi')
plt.ylabel('Rata-rata Hasil Panen per 1 Hektar')
plt.show()
# Out:
# Beberapa Baris Pertama Data:
#   nama_petani jenis_padi  harga_bibit  masa_pembibitan  masa_tanam  \
# 0     kartomo  impari 32        65000               17         105
# 1     sarinah  rojo lele       105000               17         115
# 2      miyono      ir 64        55000               17         110
# 3      kamidi   ciherang        60000               21         105
# 4       nardi       m 70       105000               15          70
#
#    luas_tanah  jumlah_panen  hasil_panen
# 0           5             2           66
# 1           6             2            7
# 2           3             2           34
# 3           3             3           42
# 4           3             3           27
#
# Jenis Padi yang Direkomendasikan Berdasarkan Rata-rata Hasil Panen Tertinggi per 1 Hektar:
# ['umbul', 'bangendit', 'sukamandi']

# %% [markdown]
# ### **Rekomendasi harga padi**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari file CSV
data = pd.read_csv('data - Sheet1.csv')

# Tampilkan beberapa baris pertama data untuk melihat strukturnya
print("Beberapa Baris Pertama Data:")
print(data.head())

# Analisis data, misalnya, menghitung rata-rata harga bibit untuk setiap varietas
rata_rata_harga_bibit = data.groupby('jenis_padi')['harga_bibit'].mean()

# Rekomendasikan harga bibit berdasarkan rata-rata harga tertinggi
harga_rekomendasi = rata_rata_harga_bibit.sort_values(ascending=False).to_dict()

# Tampilkan hasil rekomendasi
print("\nRekomendasi Harga Bibit berdasarkan Rata-rata Harga Bibit Tertinggi:")
for varietas, harga in harga_rekomendasi.items():
    print(f"Varietas: {varietas}, Harga Rekomendasi: {harga}")

# Visualisasi hasil rekomendasi
plt.figure(figsize=(12, 6))
plt.bar(harga_rekomendasi.keys(), harga_rekomendasi.values(), color='skyblue')
plt.title('Rekomendasi Harga Bibit berdasarkan Rata-rata Harga Bibit Tertinggi')
plt.xlabel('Varietas Padi')
plt.ylabel('Harga Rekomendasi Bibit')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Beberapa Baris Pertama Data:
#   nama_petani jenis_padi  harga_bibit  masa_pembibitan  masa_tanam  \
# 0     kartomo  impari 32        65000               17         105
# 1     sarinah  rojo lele       105000               17         115
# 2      miyono      ir 64        55000               17         110
# 3      kamidi   ciherang        60000               21         105
# 4       nardi       m 70       105000               15          70
#
#    luas_tanah  jumlah_panen  hasil_panen
# 0           5             2           66
# 1           6             2            7
# 2           3             2           34
# 3           3             3           42
# 4           3             3           27
#
# Rekomendasi Harga Bibit berdasarkan Rata-rata Harga Bibit Tertinggi:
# Varietas: m 70, Harga Rekomendasi: 105000.0
# Varietas: rojo lele, Harga Rekomendasi: 105000.0
# Varietas: impari 32, Harga Rekomendasi: 65000.0
# Varietas: impari 42, Harga Rekomendasi: 65000.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari file CSV
data = pd.read_csv('data - Sheet1.csv')

# Tampilkan beberapa baris pertama data untuk melihat strukturnya
print("Beberapa Baris Pertama Data:")
print(data.head())

# Analisis data, menghitung rata-rata hasil panen untuk setiap varietas
rata_rata_hasil_panen = data.groupby('jenis_padi')['hasil_panen'].mean()

# Rekomendasikan bibit berdasarkan hasil panen terbanyak
padi_padi = rata_rata_hasil_panen.sort_values(ascending=False).to_dict()

# Tampilkan hasil rekomendasi
print("\nJenis Padi Berdasarkan Harga")
for varietas, jumlah in padi_padi.items():
    print(f"Varietas: {varietas}, Ton: {jumlah}")

# Visualisasi hasil rekomendasi
plt.figure(figsize=(12, 6))
plt.bar(padi_padi.keys(), padi_padi.values(), color='lightgreen')
plt.title('Jenis Padi Berdasarkan Jumlah Panen')
plt.xlabel('Varietas Padi')
plt.ylabel('Hasil Panen Dalam Ton')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Beberapa Baris Pertama Data:
#   nama_petani jenis_padi  harga_bibit  masa_pembibitan  masa_tanam  \
# 0     kartomo  impari 32        65000               17         105
# 1     sarinah  rojo lele       105000               17         115
# 2      miyono      ir 64        55000               17         110
# 3      kamidi   ciherang        60000               21         105
# 4       nardi       m 70       105000               15          70
#
#    luas_tanah  jumlah_panen  hasil_panen
# 0           5             2           66
# 1           6             2            7
# 2           3             2           34
# 3           3             3           42
# 4           3             3           27
#
# Jenis Padi Berdasarkan Harga
# Varietas: umbul, Ton: 109.0
# Varietas: impari 42, Ton: 61.666666666666664
# Varietas: bangendit, Ton: 54.0
# Varietas: sukamandi, Ton: 43.5
# Varietas: ciherang, Ton: 42.0
# Varietas: ir 64, Ton: 34.0
# Varietas: impari 32, Ton: 30.0
# ...

# %% [markdown]
# #**Harga Bibit berdasarkan Hasil Panen**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari file CSV
data = pd.read_csv('data - Sheet1.csv')

# Tampilkan beberapa baris pertama data untuk melihat strukturnya
print("Beberapa Baris Pertama Data:")
print(data.head())

# Analisis data, menghitung rata-rata hasil panen dan harga bibit untuk setiap varietas
rata_rata_hasil_panen = data.groupby('jenis_padi')['hasil_panen'].mean()
rata_rata_harga_bibit = data.groupby('jenis_padi')['harga_bibit'].mean()

# Gabungkan hasil panen dan harga bibit ke dalam satu DataFrame baru
rekomendasi_df = pd.DataFrame({'hasil_panen': rata_rata_hasil_panen, 'harga_bibit': rata_rata_harga_bibit})

# Rekomendasikan harga bibit berdasarkan hasil panen terbanyak
rekomendasi_df = rekomendasi_df.sort_values(by='hasil_panen', ascending=False)

# Tampilkan hasil rekomendasi
print("\nRekomendasi Harga Bibit berdasarkan Hasil Panen Terbanyak:")
print(rekomendasi_df[['hasil_panen', 'harga_bibit']].head())

# Visualisasi hasil rekomendasi
plt.figure(figsize=(12, 6))
plt.bar(rekomendasi_df.index, rekomendasi_df['harga_bibit'], color='lightgreen')
plt.title('Harga Bibit berdasarkan Hasil Panen')
plt.xlabel('Varietas Padi')
plt.ylabel('Rekomendasi Harga Bibit')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Beberapa Baris Pertama Data:
#   nama_petani jenis_padi  harga_bibit  masa_pembibitan  masa_tanam  \
# 0     kartomo  impari 32        65000               17         105
# 1     sarinah  rojo lele       105000               17         115
# 2      miyono      ir 64        55000               17         110
# 3      kamidi   ciherang        60000               21         105
# 4       nardi       m 70       105000               15          70
#
#    luas_tanah  jumlah_panen  hasil_panen
# 0           5             2           66
# 1           6             2            7
# 2           3             2           34
# 3           3             3           42
# 4           3             3           27
#
# Rekomendasi Harga Bibit berdasarkan Hasil Panen Terbanyak:
#             hasil_panen  harga_bibit
# jenis_padi
# umbul        109.000000      55000.0
# impari 42     61.666667      65000.0
# bangendit     54.000000      60000.0
# sukamandi     43.500000      65000.0
# ...

# %% [markdown]
# #**Harga Bibit berdasarkan Hasil Panen Terbanyak dan Harga Terendah**
